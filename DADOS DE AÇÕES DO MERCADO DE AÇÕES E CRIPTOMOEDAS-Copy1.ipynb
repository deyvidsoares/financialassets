# %% [markdown]
# # YAHOO FINANCE

# %%
# !pip install Yfinance

# %%
# VALE,BTC-USD,OXY,PETR4 
# in this study we will use these examples as a starting point, but according to your preference it can be changed as ordered

# %%
#!pip install Yfinance
import yfinance as yf
from pandas import json_normalize
import pandas as pd

# %% [markdown]
# # Criando um Ticker

# %%
ticker = yf.Ticker('VALE') # we can use many financial assets

# %% [markdown]
# # Cotações

# %%
start = '2020-05-23'
end = '2019-05-23'
ticker.history(period='1y', interval='1d').plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Balanço Patrimonial anual

# %%
ticker.balance_sheet.T # we can use another asset that has a balance sheet
# Out:
#             Intangible Assets    Total Liab  Total Stockholder Equity  \
#
# 2020-12-31       3.116800e+10  2.971440e+11              1.857850e+11
# 2019-12-31       1.962900e+10  2.125220e+11              1.614800e+11
# 2018-12-31       1.669500e+10  1.680300e+11              1.704030e+11
# 2017-12-31       1.450100e+10  1.799910e+11              1.437580e+11
#
#             Minority Interest  Other Current Liab  Total Assets  Common Stock  \
#
# 2020-12-31      -4.799000e+09        4.206700e+10  4.781300e+11  7.730000e+10
# 2019-12-31      -4.331000e+09        2.513300e+10  3.696710e+11  7.730000e+10
# 2018-12-31       3.280000e+09        7.046000e+09  3.417130e+11  7.730000e+10
# 2017-12-31       4.348000e+09        1.934300e+10  3.280970e+11  7.730000e+10
#
#             Other Current Assets  Retained Earnings    Other Liab  ...  \
#                                                                    ...
# 2020-12-31          1.974000e+09       3.659800e+10  1.232040e+11  ...
# ...

# %% [markdown]
# # Balanço Patrimonial Trimestral

# %%
ticker.quarterly_balance_sheet # we can use another asset that has a balance sheet
# Out:
#                                     2021-03-31    2020-12-31    2020-09-30  \
# Intangible Assets                 3.109600e+10  3.116800e+10  1.974400e+10
# Total Liab                        2.936670e+11  2.971440e+11  2.637760e+11
# Total Stockholder Equity          2.074870e+11  1.857850e+11  1.946400e+11
# Minority Interest                -5.585000e+09 -4.799000e+09 -7.278000e+09
# Other Current Liab                3.496900e+10  4.206700e+10  2.661600e+10
# Total Assets                      4.955690e+11  4.781300e+11  4.511380e+11
# Common Stock                      7.730000e+10  7.730000e+10  7.730000e+10
# Other Current Assets              2.568000e+09  1.974000e+09  3.149000e+09
# Retained Earnings                 5.163800e+10  3.659800e+10  3.811500e+10
# Other Liab                        1.204650e+11  1.232040e+11  1.002080e+11
# Good Will                         1.824700e+10  1.714100e+10  1.756300e+10
# ...

# %% [markdown]
# # Fluxo de Caixa anual

# %%
ticker.cashflow
# Out:
#                                              2020-12-31    2019-12-31  \
# Investments                               -1.904000e+09 -3.695000e+09
# Change To Liabilities                     -9.320000e+08  2.836000e+09
# Total Cashflows From Investing Activities -2.423400e+10 -2.654000e+10
# Net Borrowings                            -3.130000e+08 -1.087900e+10
# Total Cash From Financing Activities      -1.804100e+10 -1.488400e+10
# Change To Operating Activities            -5.103000e+09 -8.124000e+09
# Net Income                                 2.671300e+10 -6.672000e+09
# Change In Cash                             4.045900e+10  7.214000e+09
# Effect Of Exchange Rate                    7.605000e+09  1.356000e+09
# Total Cash From Operating Activities       7.520800e+10  4.728200e+10
# Depreciation                               1.701700e+10  1.693300e+10
# Other Cashflows From Investing Activities -1.833000e+09 -5.104000e+09
# ...

# %% [markdown]
# # Fluxo de Caixa Trimestral

# %%
ticker.quarterly_cashflow
# Out:
#                                              2021-03-31    2020-12-31  \
# Investments                               -4.306000e+09 -4.184000e+09
# Change To Liabilities                     -1.452000e+09  3.280000e+08
# Total Cashflows From Investing Activities -1.312200e+10 -1.047800e+10
# Net Borrowings                            -5.584000e+09 -1.917000e+09
# Total Cash From Financing Activities      -2.746500e+10 -1.097000e+09
# Change To Operating Activities            -3.237000e+09 -5.550000e+08
# Net Income                                 3.056400e+10  4.825000e+09
# Change In Cash                             3.313000e+09  2.019700e+10
# Effect Of Exchange Rate                    5.590000e+09 -2.975000e+09
# Total Cash From Operating Activities       3.831000e+10  3.482600e+10
# Depreciation                               3.971000e+09  4.927000e+09
# Other Cashflows From Investing Activities -1.410000e+08 -2.240000e+08
# ...

# %% [markdown]
# # Financeiro anual

# %%
ticker.financials
# Out:
#                                             2020-12-31      2019-12-31  \
# Research Development                      2293000000.0    1765000000.0
# Effect Of Accounting Charges                      None            None
# Income Before Tax                        27928000000.0  -11206000000.0
# Minority Interest                        -4799000000.0   -4331000000.0
# Net Income                               26713000000.0   -6672000000.0
# Selling General Administrative            2857000000.0    1924000000.0
# Gross Profit                            109829000000.0   64615000000.0
# Ebit                                     97929000000.0   52208000000.0
# Operating Income                         97929000000.0   52208000000.0
# Other Operating Expenses                  2233000000.0    1720000000.0
# Interest Expense                        -12748000000.0   -9934000000.0
# Extraordinary Items                               None            None
# ...

# %% [markdown]
# # Financeiro Trimestral

# %%
ticker.quarterly_financials
# Out:
#                                            2021-03-31     2020-12-31  \
# Research Development                      552000000.0    817000000.0
# Effect Of Accounting Charges                     None           None
# Income Before Tax                       40139000000.0   5331000000.0
# Minority Interest                       -5585000000.0  -4799000000.0
# Net Income                              30564000000.0   4825000000.0
# Selling General Administrative            568000000.0    993000000.0
# Gross Profit                            43904000000.0  48013000000.0
# Ebit                                    42039000000.0  44168000000.0
# Operating Income                        42039000000.0  44168000000.0
# Other Operating Expenses                  -47000000.0    998000000.0
# Interest Expense                        -6496000000.0  -5082000000.0
# Extraordinary Items                              None           None
# Non Recurring                                    None           None
# ...

# %% [markdown]
# # Informações e Estatistica

# %%
ticker.get_info()['lastDividendDate']
# Out:
# 1614902400

# %%
info = json_normalize(ticker.get_info())

# %%
info.head()
# Out:
#          zip           sector  fullTimeEmployees  \
# 0  22250-145  Basic Materials              74316
#
#                                  longBusinessSummary            city  \
# 0  Vale S.A., together with its subsidiaries, pro...  Rio De Janeiro
#
#              phone state country companyOfficers              website  ...  \
# 0  55 21 3485 3900    RJ  Brazil              []  http://www.vale.com  ...
#
#    dateShortInterest pegRatio lastCapGain shortPercentOfFloat  \
# 0         1619740800     0.13        None                None
#
#    sharesShortPriorMonth  impliedSharesOutstanding  category  \
# 0               60120651                      None      None
#
#    fiveYearAverageReturn  regularMarketPrice  \
# 0                   None               20.45
#
#                              logo_url
# 0  https://logo.clearbit.com/vale.com
#
# [1 rows x 124 columns]

# %%
len(info.columns)
# Out:
# 124

# %%
selected = (c for c in list(info.columns) if 'divi' in c) #PE, Dividend, beta

# %%
info[selected]
# Out:
#    dividendRate  dividendYield
# 0          1.19          0.058

# %% [markdown]
# # Detentores de fundo mútuo

# %%
ticker.get_institutional_holders()
# Out:
#                                  Holder     Shares Date Reported   % Out  \
# 0     Capital Research Global Investors  269889943    2021-03-30  0.0511
# 1       Capital International Investors  167132674    2021-03-30  0.0316
# 2               Capital World Investors  121399165    2021-03-30  0.0230
# 3                          Invesco Ltd.   75100250    2021-03-30  0.0142
# 4                        Blackrock Inc.   69968346    2021-03-30  0.0132
# 5          Fisher Asset Management, LLC   38070253    2021-03-30  0.0072
# 6                      GQG Partners LLC   36787025    2021-03-30  0.0070
# 7            Standard Life Aberdeen PLC   34888718    2021-03-30  0.0066
# 8  Schroder Investment Management Group   27918283    2021-03-30  0.0053
# 9           Baillie Gifford and Company   23078653    2021-03-30  0.0044
#
#         Value
# 0  4690687209
# 1  2904765874
# 2  2109917487
# 3  1305242345
# 4  1216049853
# 5   661660997
# 6   639358494
# 7   606365918
# 8   485219758
# ...

# %%
ticker.get_mutualfund_holders()
# Out:
#                                             Holder     Shares Date Reported  \
# 0                          Europacific Growth Fund  159866127    2021-03-30
# 1                  Invesco Developing Markets Fund   61414202    2021-01-30
# 2                         New Perspective Fund Inc   59581644    2021-03-30
# 3             Capital World Growth and Income Fund   51465552    2021-03-30
# 4                     Capital Income Builder, Inc.   49239786    2021-03-30
# 5                           American Balanced Fund   43461900    2021-03-30
# 6                       Growth Fund Of America Inc   42446552    2021-03-30
# 7                             New World Fund, Inc.   32470206    2021-03-30
# 8                        Fundamental Investors Inc   22662872    2021-03-30
# 9  American Funds Insurance Ser-International Fund   20302542    2021-03-30
#
#     % Out       Value
# 0  0.0303  2778473287
# 1  0.0116   991839362
# 2  0.0113  1035528972
# 3  0.0097   894471293
# ...

# %% [markdown]
# # Distribuição acionária

# %%
ticker.get_major_holders()
# Out:
#         0                                      1
# 0   0.00%        % of Shares Held by All Insider
# 1  25.29%       % of Shares Held by Institutions
# 2  25.29%        % of Float Held by Institutions
# 3     591  Number of Institutions Holding Shares
